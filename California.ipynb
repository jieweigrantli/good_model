# %%
import warnings
warnings.filterwarnings("ignore")

import os
import sys
import time
import json
import numpy as np
import pandas as pd
import geopandas as gpd
import pickle as pkl
import networkx as nx
import matplotlib.pyplot as plt
import pyomo.environ as pe

import good
from good.reload import deep_reload

# %% [markdown]
# This notebook shows how to load a default dataset, create a subgraph, and aggregate assets.

# %%
'''
Creating a California subgraph
'''
deep_reload(good)

graph = good.graph.graph_from_json('Examples/WEC.json')

nodes = ['WEC_BANC', 'WEC_CALN', 'WEC_LADW', 'WEC_SDGE', 'WECC_IID' , 'WECC_SCE']
graph = good.graph.subgraph(graph, nodes)
graph.nodes
# Out:
# NodeView(('WEC_BANC', 'WEC_CALN', 'WEC_LADW', 'WEC_SDGE', 'WECC_IID', 'WECC_SCE'))

# %%
'''
Aggregating Assets to reduce complexity
'''
deep_reload(good)

clustering = good.aggregate.default_clustering

clustering['resolution'] = 2

graph = good.aggregate.aggregate(graph, clustering = clustering)
# Out:
#  [-------------->] (6/6) 100.00%, 0.37 it/s, 18.67 s elapsed, 0.00 s remaining

# %%
'''
Saving the graph
'''
deep_reload(good)

good.graph.graph_to_json(graph, 'Examples/California.json')
